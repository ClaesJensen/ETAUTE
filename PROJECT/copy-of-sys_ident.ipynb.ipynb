# %% [markdown]
# # ETAUTE test for pink noise REW measurements
#
# ## Imports

# %%
import numpy as np
import soundfile as sf

import matplotlib
matplotlib.use('macosx') # Use the native Mac backend
from matplotlib import pyplot as plt
from scipy.signal import welch

import scipy
import dsp_tools

plt.style.use('default')

# %% [markdown]
# ## Import and plot tihi

# %%
data_high, samplerate_high = sf.read('./HØJ.wav')
data_middle, samplerate_middle = sf.read('./MELLEM.wav')
data_low, samplerate_low = sf.read('./LAV.wav')
data_ref , samplerate_ref = sf.read('./PINK_NOISE_REFERENCE.wav')

# %% [markdown]
# Plots

# %%
dsp_tools.plot_signal_time(data_high, fs=48000, title="Speaker HØJ - Time Domain");

# %%
plt.plot(data_middle)
plt.show()

# %%
plt.plot(data_low)

# %%
# %matplotlib osx 
data_ref.shape
data_low.shape
shift = 4000
plt.plot(data_low[shift:shift+1000])
# plt.plot(data_ref[:1000])
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'osx')
#       2 data_ref.shape
#       3 data_low.shape
#
# File ~/.pyenv/versions/3.13.2/envs/dsp/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
