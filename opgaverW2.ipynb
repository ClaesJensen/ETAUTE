# %%
import numpy
import math

# %% [markdown]
# Vi ved at et lydtryksniveau på 0 dB svarer til et lydtryk på 20 μPa.
# a) Hvor stort et lydtryksniveau (i dB) svarer 1 Pa til?
# b) Find det normale lufttryk ved jordoverfladen i pascal.
# c) Hvor stort er det normale lufttryk omregnet til dB i forhold til 20
# μPa?

# %%
Lp = 20*math.log10(1/20e-6)
print(Lp)
# Out:
# 93.97940008672037

# %% [markdown]
# b)
# 1atm=101325Pa
#
# C)
# Hvor stort er det normale lufttryk omregnet til dB i forhold til 20
# μPa?

# %%
20*math.log10(101325/20e-6)
# Out:
# 194.09373233499497

# %%
20*math.log10(500e-6/20e-6)
# Out:
# 27.958800173440753

# %% [markdown]
# Nej bro den skal være sådan 40-50dB bro
#
#
# B)
# OMkring
#
#
# C)
# 6-7dB? jeg ved det sgu da ik bro
